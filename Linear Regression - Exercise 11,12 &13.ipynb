# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
np.random.seed(7)
x = np.random.random((300,1))
y = 2*x + np.random.random((300,1))

# %% [markdown]
# ### (a) Perform a simple linear regression of y onto x, without an intercept. Report the coefficient estimate ˆβ, the standard error of this coefficient estimate, and the t-statistic and p-value associated with the null hypothesis H0 : β = 0.

# %%
est = sm.OLS(y, x)
resp = est.fit()
print(resp.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.943
# Model:                            OLS   Adj. R-squared (uncentered):              0.943
# Method:                 Least Squares   F-statistic:                              4919.
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):                   1.05e-187
# Time:                        19:49:23   Log-Likelihood:                         -142.31
# No. Observations:                 300   AIC:                                      286.6
# Df Residuals:                     299   BIC:                                      290.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             2.7630      0.039     70.136      0.000       2.685       2.840
# ==============================================================================
# Omnibus:                       13.871   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                6.142
# Skew:                          -0.008   Prob(JB):                       0.0464
# Kurtosis:                       2.299   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### (b) Now perform a simple linear regression of x onto y without an intercept, and report the coefficient estimate, its standard error, and the corresponding t-statistic and p-values associated with the null hypothesis H0 : β = 0. Comment on these results.

# %%
est = sm.OLS(x, y)
resp = est.fit()
print(resp.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.943
# Model:                            OLS   Adj. R-squared (uncentered):              0.943
# Method:                 Least Squares   F-statistic:                              4919.
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):                   1.05e-187
# Time:                        19:49:23   Log-Likelihood:                          171.43
# No. Observations:                 300   AIC:                                     -340.9
# Df Residuals:                     299   BIC:                                     -337.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3412      0.005     70.136      0.000       0.332       0.351
# ==============================================================================
# Omnibus:                       10.176   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                5.087
# Skew:                           0.017   Prob(JB):                       0.0786
# Kurtosis:                       2.363   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### (c) What is the relationship between the results obtained in (a) and (b)?

# %% [markdown]
# they have the same R2 and t-static value.

# %% [markdown]
# ### (f) In R, show that when regression is performed with an intercept, the t-statistic for H0 : β1 = 0 is the same for the regression of y onto x as it is for the regression of x onto y.

# %%
X = sm.add_constant(x)
est = sm.OLS(y, X)
resp = est.fit()
print(resp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     1172.
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):          2.78e-105
# Time:                        19:49:23   Log-Likelihood:                -60.200
# No. Observations:                 300   AIC:                             124.4
# Df Residuals:                     298   BIC:                             131.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4954      0.034     14.737      0.000       0.429       0.562
# x1             2.0162      0.059     34.233      0.000       1.900       2.132
# ==============================================================================
# Omnibus:                      223.261   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.648
# Skew:                           0.062   Prob(JB):                     5.41e-05
# Kurtosis:                       1.752   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y = sm.add_constant(y)
est = sm.OLS(x, Y)
resp = est.fit()
print(resp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     1172.
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):          2.78e-105
# Time:                        19:49:23   Log-Likelihood:                 184.15
# No. Observations:                 300   AIC:                            -364.3
# Df Residuals:                     298   BIC:                            -356.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0963      0.019     -5.134      0.000      -0.133      -0.059
# x1             0.3954      0.012     34.233      0.000       0.373       0.418
# ==============================================================================
# Omnibus:                       31.625   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.662
# Skew:                          -0.010   Prob(JB):                      0.00798
# Kurtosis:                       2.121   Cond. No.                         5.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 12. This problem involves simple linear regression without an intercept.

# %% [markdown]
# ### (a) Recall that the coefficient estimate ˆ β for the linear regression of Y onto X without an intercept is given by (3.38). Under what circumstance is the coefficient estimate for the regression of X onto Y the same as the coefficient estimate for the regression of Y onto X?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (b) Generate an example in R with n = 100 observations in which the coefficient estimate for the regression of X onto Y is different from the coefficient estimate for the regression of Y onto X.

# %%
np.random.seed(10)
x = np.random.random((100,1))
y = np.log(x)

# %%
est = sm.OLS(y, x)
resp = est.fit()
print(resp.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.109
# Model:                            OLS   Adj. R-squared (uncentered):              0.100
# Method:                 Least Squares   F-statistic:                              12.17
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):                    0.000727
# Time:                        19:49:24   Log-Likelihood:                         -170.64
# No. Observations:                 100   AIC:                                      343.3
# Df Residuals:                      99   BIC:                                      345.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.8378      0.240     -3.488      0.001      -1.314      -0.361
# ==============================================================================
# Omnibus:                       33.945   Durbin-Watson:                   1.782
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.304
# Skew:                          -1.446   Prob(JB):                     1.33e-13
# Kurtosis:                       5.423   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
est = sm.OLS(x, y)
resp = est.fit()
print(resp.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.109
# Model:                            OLS   Adj. R-squared (uncentered):              0.100
# Method:                 Least Squares   F-statistic:                              12.17
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):                    0.000727
# Time:                        19:49:24   Log-Likelihood:                         -77.728
# No. Observations:                 100   AIC:                                      157.5
# Df Residuals:                      99   BIC:                                      160.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1307      0.037     -3.488      0.001      -0.205      -0.056
# ==============================================================================
# Omnibus:                        4.136   Durbin-Watson:                   1.229
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                3.894
# Skew:                          -0.420   Prob(JB):                        0.143
# Kurtosis:                       2.520   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## (c) Generate an example in R with n = 100 observations in which the coefficient estimate for the regression of X onto Y is the same as the coefficient estimate for the regression of Y onto X.

# %%
np.random.seed(10)
x = np.random.random((100,1))
y = np.random.permutation(x)

# %%
est = sm.OLS(y, x)
resp = est.fit()
print(resp.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.563
# Model:                            OLS   Adj. R-squared (uncentered):              0.559
# Method:                 Least Squares   F-statistic:                              127.7
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):                    1.63e-19
# Time:                        19:49:24   Log-Likelihood:                         -42.098
# No. Observations:                 100   AIC:                                      86.20
# Df Residuals:                      99   BIC:                                      88.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7505      0.066     11.301      0.000       0.619       0.882
# ==============================================================================
# Omnibus:                        2.814   Durbin-Watson:                   1.547
# Prob(Omnibus):                  0.245   Jarque-Bera (JB):                2.400
# Skew:                          -0.268   Prob(JB):                        0.301
# Kurtosis:                       2.462   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
est = sm.OLS(x, y)
resp = est.fit()
print(resp.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.563
# Model:                            OLS   Adj. R-squared (uncentered):              0.559
# Method:                 Least Squares   F-statistic:                              127.7
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):                    1.63e-19
# Time:                        19:49:25   Log-Likelihood:                         -42.098
# No. Observations:                 100   AIC:                                      86.20
# Df Residuals:                      99   BIC:                                      88.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7505      0.066     11.301      0.000       0.619       0.882
# ==============================================================================
# Omnibus:                        4.059   Durbin-Watson:                   1.693
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                3.425
# Skew:                           0.352   Prob(JB):                        0.180
# Kurtosis:                       2.429   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 13. In this exercise you will create some simulated data and will fit simple linear regression models to it. Make sure to use set.seed(1) prior to starting part (a) to ensure consistent results.

# %% [markdown]
# ### (a) Using the rnorm() function, create a vector, x, containing 100 observations drawn from a N(0, 1) distribution. This represents a feature, X.

# %%
np.random.seed(15)
X = np.random.normal(scale=1,size=(100,1))
X.std()
# Out:
# 1.0177526154836587

# %% [markdown]
# ### (b) Using the rnorm() function, create a vector, eps, containing 100 observations drawn from a N(0, 0.25) distribution i.e. a normal distribution with mean zero and variance 0.25.

# %%
eps = np.random.normal(scale=0.25,size=(100,1))

# %%
eps.std()
# Out:
# 0.25470145585177484

# %% [markdown]
# ### (c) Using x and eps, generate a vector y according to the model Y = −1 + 0.5X + eps.

# %%
Y = - 1 + 0.5*X + eps

# %% [markdown]
# ### (d) Create a scatterplot displaying the relationship between x and y. Comment on what you observe.

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(X, Y, 'bo')
ax.set(title="Plot",
      xlabel="X",
      ylabel="Y");

# %% [markdown]
# ### (e) Fit a least squares linear model to predict y using x. Comment on the model obtained. How do ˆ β0 and ˆ β1 compare to β0 and β1?

# %%
X1 = sm.add_constant(X)
est = sm.OLS(Y, X1)
resp = est.fit()
print(resp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     464.1
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           5.94e-39
# Time:                        19:49:26   Log-Likelihood:                -3.9468
# No. Observations:                 100   AIC:                             11.89
# Df Residuals:                      98   BIC:                             17.10
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0119      0.025    -39.758      0.000      -1.062      -0.961
# x1             0.5382      0.025     21.544      0.000       0.489       0.588
# ==============================================================================
# Omnibus:                        3.056   Durbin-Watson:                   1.833
# Prob(Omnibus):                  0.217   Jarque-Bera (JB):                2.493
# Skew:                          -0.255   Prob(JB):                        0.288
# Kurtosis:                       3.581   Cond. No.                         1.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### (f) Display the least squares line on the scatterplot obtained in (d). Draw the population regression line on the plot, in a different color. Use the legend() command to create an appropriate legend.

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(X, Y, 'bo')
ax.plot(X, resp.predict(),color='red')
ax.set(title="Plot",
      xlabel="X",
      ylabel="Y");

# %% [markdown]
# ### (g) Now fit a polynomial regression model that predicts y using x and x2. Is there evidence that the quadratic term improves the model fit? Explain your answer.

# %%
x2 = pd.Series(x.reshape(100))
df = pd.DataFrame({'X': x2})
df['X**2'] = x2**2
X1 = sm.add_constant(df)
est = sm.OLS(Y, X1)
resp1 = est.fit()
print(resp1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                   0.02111
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):              0.979
# Time:                        19:49:27   Log-Likelihood:                -91.264
# No. Observations:                 100   AIC:                             188.5
# Df Residuals:                      97   BIC:                             196.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0009      0.185     -5.424      0.000      -1.367      -0.635
# X             -0.1461      0.840     -0.174      0.862      -1.814       1.521
# X**2           0.1144      0.825      0.139      0.890      -1.523       1.751
# ==============================================================================
# Omnibus:                        1.058   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.589   Jarque-Bera (JB):                1.108
# Skew:                           0.235   Prob(JB):                        0.575
# Kurtosis:                       2.789   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### (h) Repeat (a)–(f) after modifying the data generation process in such a way that there is less noise in the data. The model (3.39) should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term in (b). Describe your results.

# %%
eps = np.random.normal(scale=0.125,size=(100,1))

# %%
Y2 = - 1 + 0.5*X + eps
X3 = sm.add_constant(X)
est2 = sm.OLS(Y2, X3)
resp2 = est2.fit()
print(resp2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     1835.
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           2.86e-65
# Time:                        19:49:28   Log-Likelihood:                 75.586
# No. Observations:                 100   AIC:                            -147.2
# Df Residuals:                      98   BIC:                            -142.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.9981      0.011    -86.869      0.000      -1.021      -0.975
# x1             0.4832      0.011     42.841      0.000       0.461       0.506
# ==============================================================================
# Omnibus:                        0.821   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.735
# Skew:                           0.207   Prob(JB):                        0.693
# Kurtosis:                       2.930   Cond. No.                         1.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(X, Y2, 'bo')
ax.plot(X, resp2.predict(),color='red')
ax.set(title="Plot",
      xlabel="X",
      ylabel="Y");

# %% [markdown]
# ### (i) Repeat (a)–(f) after modifying the data generation process in such a way that there is more noise in the data. The model (3.39) should remain the same.

# %%
eps = np.random.normal(scale=0.5,size=(100,1))

# %%
Y3 = - 1 + 0.5*X + eps
X4 = sm.add_constant(X)
est3 = sm.OLS(Y3, X4)
resp3 = est3.fit()
print(resp3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     113.6
# Date:                Wed, 02 Dec 2020   Prob (F-statistic):           4.57e-18
# Time:                        19:49:28   Log-Likelihood:                -73.986
# No. Observations:                 100   AIC:                             152.0
# Df Residuals:                      98   BIC:                             157.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0592      0.051    -20.657      0.000      -1.161      -0.957
# x1             0.5364      0.050     10.657      0.000       0.436       0.636
# ==============================================================================
# Omnibus:                        0.676   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.713   Jarque-Bera (JB):                0.778
# Skew:                           0.083   Prob(JB):                        0.678
# Kurtosis:                       2.601   Cond. No.                         1.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(X, Y3, 'bo')
ax.plot(X, resp3.predict(),color='red')
ax.set(title="Plot",
      xlabel="X",
      ylabel="Y");

# %%
resp.conf_int(alpha = 0.05, cols=None)
# Out:
# array([[-1.06242507, -0.96140847],
#        [ 0.48865382,  0.58781053]])

# %%
resp1.conf_int(alpha = 0.05, cols=None)
# Out:
#               0         1
# const -1.367222 -0.634669
# X     -1.813626  1.521363
# X**2  -1.522568  1.751442

# %%
resp2.conf_int(alpha = 0.05, cols=None)
# Out:
# array([[-1.02090486, -0.97530278],
#        [ 0.46079336,  0.50555582]])

# %%
resp3.conf_int(alpha = 0.05, cols=None)
# Out:
# array([[-1.16091835, -0.95741632],
#        [ 0.4364731 ,  0.6362283 ]])
