# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample

# %%
default = sm.datasets.get_rdataset('Default', 'ISLR')

# %%
print(default.__doc__)
# Out:
# ======= ===============
# Default R Documentation
# ======= ===============
#
# Credit Card Default Data
# ------------------------
#
# Description
# ~~~~~~~~~~~
#
# A simulated data set containing information on ten thousand customers.
# The aim here is to predict which customers will default on their credit
# card debt.
#
# Usage
# ~~~~~
#
# ::
#
#    Default
#
# Format
# ~~~~~~
#
# A data frame with 10000 observations on the following 4 variables.
#
# ``default``
#    A factor with levels ``No`` and ``Yes`` indicating whether the
#    customer defaulted on their debt
#
# ``student``
#    A factor with levels ``No`` and ``Yes`` indicating whether the
#    customer is a student
#
# ``balance``
#    The average balance that the customer has remaining on their credit
#    card after making their monthly payment
#
# ``income``
#    Income of customer
#
# Source
# ~~~~~~
#
# Simulated data
#
# References
# ~~~~~~~~~~
#
# James, G., Witten, D., Hastie, T., and Tibshirani, R. (2013) *An
# ...

# %%
ddefault = default.data

# %%
ddefault.head()
# Out:
#   default student      balance        income
# 0      No      No   729.526495  44361.625074
# 1      No     Yes   817.180407  12106.134700
# 2      No      No  1073.549164  31767.138947
# 3      No      No   529.250605  35704.493935
# 4      No      No   785.655883  38463.495879

# %%
ddefault.isna().sum()
# Out:
# default    0
# student    0
# balance    0
# income     0
# dtype: int64

# %%
X = ddefault[['income', 'balance']]
y = ddefault['default']

# %% [markdown]
# ### (a) Fit a logistic regression model that uses income and balance to predict default.

# %%
lr = LogisticRegression()
lr.fit(X,y)
pred = lr.predict(X)
print('Train accuracy is ',accuracy_score(pred,y))
# Out:
# Train accuracy is  0.9737

# %% [markdown]
# ### (b) Using the validation set approach, estimate the test error of this model. In order to do this, you must perform the following steps:

# %% [markdown]
# #### i. Split the sample set into a training set and a validation set.

# %%
np.random.seed(1)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### ii. Fit a multiple logistic regression model using only the training observations.

# %%
lr1 = LogisticRegression()
lr1.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### iii. Obtain a prediction of default status for each individual in the validation set by computing the posterior probability of default for that individual, and classifying the individual to the default category if the posterior probability is greater than 0.5.

# %%
pred = lr.predict(X_val)

# %% [markdown]
# #### iv. Compute the validation set error, which is the fraction of the observations in the validation set that are misclassified.

# %%
print('validation error is ',1-accuracy_score(pred,y_val))
# Out:
# validation error is  0.025000000000000022

# %% [markdown]
# ### (c) Repeat the process in (b) three times, using three different splits of the observations into a training set and a validation set. Comment on the results obtained.

# %%
np.random.seed(2)

X_train2, X_val2, y_train2, y_val2 = train_test_split(X, y, test_size = 0.2)

lr2 = LogisticRegression()
lr2.fit(X_train2, y_train2)

pred2 = lr2.predict(X_val2)

print('validation error is ',1-accuracy_score(pred2,y_val2))
# Out:
# validation error is  0.02849999999999997

# %%
np.random.seed(3)

X_train3, X_val3, y_train3, y_val3 = train_test_split(X, y, test_size = 0.2)

lr3 = LogisticRegression()
lr3.fit(X_train3, y_train3)

pred3 = lr3.predict(X_val3)

print('validation error is ',1-accuracy_score(pred3,y_val3))
# Out:
# validation error is  0.030000000000000027

# %%
np.random.seed(4)

X_train4, X_val4, y_train4, y_val4 = train_test_split(X, y, test_size = 0.2)

lr4 = LogisticRegression()
lr4.fit(X_train4, y_train4)

pred4 = lr4.predict(X_val4)

print('validation error is ',1-accuracy_score(pred4,y_val4))
# Out:
# validation error is  0.024499999999999966

# %% [markdown]
# ### (d) Now consider a logistic regression model that predicts the probability of default using income, balance, and a dummy variable for student. Estimate the test error for this model using the validation set approach. Comment on whether or not including a dummy variable for student leads to a reduction in the test error rate.

# %%
X1 = pd.get_dummies(ddefault[['income', 'balance','student']], columns=['student'], drop_first = True)
y1 = ddefault['default']


np.random.seed(1)

X_train5, X_val5, y_train5, y_val5 = train_test_split(X1, y1, test_size = 0.2)

lr5 = LogisticRegression()
lr5.fit(X_train5, y_train5)

pred5 = lr5.predict(X_val5)

print('validation error is ',1-accuracy_score(pred5,y_val5))
# Out:
# validation error is  0.03300000000000003

# %% [markdown]
# ## 6. We continue to consider the use of a logistic regression model to predict the probability of default using income and balance on the Default data set. In particular, we will now compute estimates for the standard errors of the income and balance logistic regression coefficients in two different ways: (1) using the bootstrap, and (2) using the standard formula for computing the standard errors in the glm() function. Do not forget to set a random seed before beginning your analysis.

# %% [markdown]
# ### (a) Using the summary() and glm() functions, determine the estimated standard errors for the coefficients associated with income and balance in a multiple logistic regression model that uses both predictors.

# %%
# from sklearn.linear_model import LinearRegression
# np.random.seed(1)

# X = ddefault[['income', 'balance']]
# y = ddefault['default']



# lr = LogisticRegression()
# lr.fit(X,y)
# print(f'intercept: {lr.intercept_} coef:{lr.coef_}')
default_aux = pd.get_dummies(ddefault, columns=['student', 'default'], drop_first = True)
default_aux['default'] = default_aux['default_Yes']

X = sm.add_constant(default_aux[['income', 'balance']])
y = default_aux['default']

clf_lr = sm.Logit(y,X).fit()
print(clf_lr.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 10
# C:\Users\Amer Kamal\Documents\AI\boston_LR_project\env\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\Amer Kamal\Documents\AI\boston_LR_project\env\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
#                            Logit Regression Results
# ...
# Dep. Variable:                default   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9997
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 23 Feb 2021   Pseudo R-squ.:                     inf
# ...

# %%
print(clf_lr.params)
# Out:
# const     -11.540468
# income      0.000021
# balance     0.005647
# dtype: float64

# %% [markdown]
# ### (b) Write a function, boot.fn(), that takes as input the Default data set as well as an index of the observations, and that outputs the coefficient estimates for income and balance in the multiple logistic regression model.

# %%
# def boot_fn(data,index):
#     X = data[['income', 'balance']].loc[index]
#     y = data['default'].loc[index]
#     lr = LogisticRegression()
#     lr.fit(X, y)
#     intercept = lr.intercept_[0]
#     coef = lr.coef_[0]
#     return [intercept,coef[0],coef[1]]

def boot_fn(data,index):
    X = sm.add_constant(data[['income', 'balance']].loc[index])
    y = data['default'].loc[index]
    

    clf_lr = sm.Logit(y,X).fit()
    
    return [clf_lr.params.const,clf_lr.params.income,clf_lr.params.balance]

# %% [markdown]
# ### (c) Use the boot() function together with your boot.fn() function to estimate the standard errors of the logistic regression coefficients for income and balance.

# %%
def boot(data,func,R):
    estimates = []
    for i in range(R):
        estimates.append(func(data,resample(np.arange(0,len(data)), n_samples=len(data), replace=True)))
    df = pd.DataFrame(estimates)
    print(df)
    bootstrap_statistics = {'estimated_value':np.mean(np.array(df.values),axis=0),'std_error':np.std(np.array(df.values),axis=0)}   
    return bootstrap_statistics

# %%
ddefault1 = ddefault.reset_index()

# %%
boot(default_aux,boot_fn,1000)
# Out:
# C:\Users\Amer Kamal\Documents\AI\boston_LR_project\env\lib\site-packages\statsmodels\discrete\discrete_model.py:1799: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\Amer Kamal\Documents\AI\boston_LR_project\env\lib\site-packages\statsmodels\discrete\discrete_model.py:1852: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 10
# Optimization terminated successfully.
# ...

# %% [markdown]
# ### (d) Comment on the estimated standard errors obtained using the glm() function and using your bootstrap function.

# %% [markdown]
# #### The two methods are very close
